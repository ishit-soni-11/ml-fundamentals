# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data=pd.read_csv('/content/Titanic-Dataset.csv')

# %%
print(Data.shape)
# Out:
# (891, 12)

# %%
print(Data.info)
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
print(Data.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(Data['Survived'].value_counts())
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
print("People who survived in Titanic:", Data['Survived'].value_counts()[1])
# Out:
# People who survived in Titanic: 342

# %%
print("Total number of people in titanic:", Data.count())
# Out:
# Total number of people in titanic: PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
print("People who have not survived in Titanic:", Data['Survived'].value_counts()[0])
# Out:
# People who have not survived in Titanic: 549

# %%
Percentage_Of_People_Who_Survived=(Data['Survived'].value_counts()[1]/Data.shape[0] * 100)

# %%
print(Percentage_Of_People_Who_Survived)
# Out:
# 38.38383838383838

# %%
Survivers_Avg_Age=Data.groupby('Survived')['Age'].mean()

# %%
print(Survivers_Avg_Age)
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
Survival_rates = Data.groupby('Pclass')['Survived'].mean()

# %%
print(Survival_rates)
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
print('passenger class who had the highest survival rate',survival_rates[1])
# Out:
# passenger class who had the highest survival rate 0.6296296296296297

# %%
Fair_Paid_Correlation=Data['Fare'].corr(Data['Survived'])

# %%
print('The correlation between Fair paid and survival',Fair_Paid_Correlation)
# Out:
# The correlation between Fair paid and survival 0.2573065223849625

# %%
print(Data.groupby('Pclass')['Fare'].mean())
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
Missing_Columns=Data.isnull().sum()

# %%
print('Missing_Columns are',Missing_Columns)
# Out:
# Missing_Columns are PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Data['FamilySize'] = Data['SibSp'] + Data['Parch'] + 1

# %%
Data['Age']=Data['Age'].fillna(Data['Age'].mean())

# %%
Missing_Columns=Data.isnull().sum()

# %%
print(Missing_Columns)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FamilySize       0
# dtype: int64

# %%
Dataframe=Data[['Sex', 'Pclass']]

# %%
print(Dataframe)
# Out:
#         Sex  Pclass
# 0      male       3
# 1    female       1
# 2    female       3
# 3    female       1
# 4      male       3
# ..      ...     ...
# 886    male       2
# 887  female       1
# 888  female       3
# 889    male       1
# 890    male       3
#
# [891 rows x 2 columns]

# %%
cols = ['Survived', 'Pclass', 'Age', 'Fare', 'SibSp']

# %%
sns.pairplot(Data[cols], hue='Survived', palette='viridis', diag_kind='kde')
plt.show()
